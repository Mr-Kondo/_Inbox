# %% [markdown]
# <a href="https://colab.research.google.com/github/MS-H2020/Open/blob/main/GTZAN_Dataset_Music_Genre_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [GTZAN Dataset - Music Genre Classification](https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.unpack_archive('/content/drive/MyDrive/archive.zip', './data')

# %% [markdown]
# ## Reffering to [Kaggle, Music Genre Classification using CNN](https://www.kaggle.com/code/soumyasharma20/music-genre-classification-using-cnn)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import json
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf

# make sure ffmpeg is installed as backend.
# !apt install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# Dataset location
SOURCE_PATH = '/content/data/Data/genres_original'

# Path to labels and processed data file, json format.
JSON_PATH = './data.json'

# Sampling rate.
sr = 22050

# Let's make sure all files have the same amount of samples and pick a duration right under 30 seconds.
TOTAL_SAMPLES = 29 * sr

# The dataset contains 999 files. Lets make it bigger.
# X amount of slices => X times more training examples.
NUM_SLICES = 10
SAMPLES_PER_SLICE = int(TOTAL_SAMPLES / NUM_SLICES)

# %%
def preprocess_data(source_path, json_path):

    # Let's create a dictionary of labels and processed data.
    mydict = {
        "labels": [],
        "mfcc": []
        }

    # Let's browse each file, slice it and generate the 13 band mfcc for each slice.
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(source_path)):
        for file in filenames:
            # exclude a corrupted wav file that makes everything crash.
            if os.path.join(dirpath, file) != '/content/data/Data/genres_original/jazz/jazz.00054.wav':
                song, sr = librosa.load(os.path.join(dirpath, file), duration=29)
                for s in range(NUM_SLICES):
                    start_sample = SAMPLES_PER_SLICE * s
                    end_sample = start_sample + SAMPLES_PER_SLICE
                    mfcc = librosa.feature.mfcc(y=song[start_sample:end_sample], sr=sr, n_mfcc=13)
                    mfcc = mfcc.T
                    mydict["labels"].append(i-1)
                    mydict["mfcc"].append(mfcc.tolist())
            else:
                pass

    # Let's write the dictionary in a json file.
    with open(json_path, 'w') as f:
        json.dump(mydict, f)
    f.close()

# %%
def load_data(json_path):

    with open(json_path, 'r') as f:
        data = json.load(f)
    f.close()

    # Let's load our data into numpy arrays for TensorFlow compatibility.
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    return X, y

# %%
def prepare_datasets(inputs, targets, split_size):

    # Creating a validation set and a test set.
    inputs_train, inputs_val, targets_train, targets_val = train_test_split(inputs, targets, test_size=split_size, stratify=targets)
    inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs_train, targets_train, test_size=split_size, stratify=targets_train)

    # Our CNN model expects 3D input shape.
    inputs_train = inputs_train[..., np.newaxis]
    inputs_val = inputs_val[..., np.newaxis]
    inputs_test = inputs_test[..., np.newaxis]

    return inputs_train, inputs_val, inputs_test, targets_train, targets_val, targets_test

# %%
def design_cnn_model(input_shape):

    # Let's design the model architecture.
    model = tf.keras.models.Sequential([

        tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        tf.keras.layers.BatchNormalization(),

        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        tf.keras.layers.BatchNormalization(),

        tf.keras.layers.Conv2D(32, (2,2), activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.3),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(len(np.unique(targets)), activation='softmax')
    ])

    return model

# %% [markdown]
# ### Reffering to RNN model : [Kaggle, intro to audio with Deep Learning](https://www.kaggle.com/code/riadalmadani/intro-to-audio-with-deep-learning)

# %%
def design_rnn_model(input_shape):

    # Let's design the model architecture.
    model = tf.keras.models.Sequential([

        # 64 represnets the number of units NOT cells
        # the number of cells equal to the numper of steps which is 130 here

        tf.keras.layers.LSTM(64,input_shape=input_shape, return_sequences=True),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(len(np.unique(targets)), activation='softmax')
    ])

    return model

# %%
def make_prediction(model, X, y, idx):

    genre_dict = {
        0 : "blues",
        1 : "classical",
        2 : "country",
        3 : "disco",
        4 : "hiphop",
        5 : "jazz",
        6 : "metal",
        7 : "pop",
        8 : "reggae",
        9 : "rock",
        }

    predictions = model.predict(X)
    genre = np.argmax(predictions[idx])

    print("\n---Now testing the model for one audio file---\nThe model predicts: {}, and ground truth is: {}.\n".format(genre_dict[genre], genre_dict[y[idx]]))

# %%
def plot_performance(hist):

    acc = hist.history['accuracy']
    val_acc = hist.history['val_accuracy']
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'r', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

# %%
if __name__ == "__main__":
    preprocess_data(source_path=SOURCE_PATH, json_path=JSON_PATH)

    inputs, targets = load_data(json_path=JSON_PATH)

    Xtrain, Xval, Xtest, ytrain, yval, ytest = prepare_datasets(inputs, targets, 0.2)

    input_shape = (Xtrain.shape[1], Xtrain.shape[2], 1)
    model = design_cnn_model(input_shape)

    # Selection of the optimizer, loss type and metrics for performance evaluation.
    model.compile(optimizer = tf.keras.optimizers.AdamW(),
                     loss='sparse_categorical_crossentropy',
                     metrics = ['accuracy']
                     )

    model.summary()

    #Training the model.
    history = model.fit(Xtrain, ytrain,
                        validation_data=(Xval, yval),
                        epochs=50,
                        batch_size=32,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)],
                        )

    plot_performance(history)

    # Testing the model on never seen before data.
    make_prediction(model, Xtest, ytest, 24)

    test_error , test_accuracy = model.evaluate(Xtest,ytest,verbose=1)
    print("Accuracy on test is {}".format(test_accuracy))
    print("Test error is {}".format(test_error))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 123, 11, 32)         │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 62, 6, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 62, 6, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 60, 4, 32)           │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 2, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 30, 2, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 29, 1, 32)           │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 15, 1, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 15, 1, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 15, 1, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 480)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          30,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 45,514 (177.79 KB)
#  Trainable params: 45,322 (177.04 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 22s 82ms/step - accuracy: 0.3567 - loss: 1.9022 - val_accuracy: 0.4384 - val_loss: 1.5394
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 116ms/step - accuracy: 0.5617 - loss: 1.2156 - val_accuracy: 0.5586 - val_loss: 1.2403
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 120ms/step - accuracy: 0.6361 - loss: 1.0231 - val_accuracy: 0.6096 - val_loss: 1.1027
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - accuracy: 0.6737 - loss: 0.8810 - val_accuracy: 0.6471 - val_loss: 0.9607
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - accuracy: 0.7169 - loss: 0.7971 - val_accuracy: 0.7057 - val_loss: 0.8465
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 116ms/step - accuracy: 0.7419 - loss: 0.7383 - val_accuracy: 0.6572 - val_loss: 0.9975
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.7686 - loss: 0.6598 - val_accuracy: 0.7302 - val_loss: 0.8022
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 136ms/step - accuracy: 0.7787 - loss: 0.6271 - val_accuracy: 0.6221 - val_loss: 1.1739
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 36s 112ms/step - accuracy: 0.7818 - loss: 0.6037 - val_accuracy: 0.7377 - val_loss: 0.7999
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 120ms/step - accuracy: 0.7995 - loss: 0.5713 - val_accuracy: 0.7237 - val_loss: 0.8487
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 105ms/step - accuracy: 0.8244 - loss: 0.5191 - val_accuracy: 0.7272 - val_loss: 0.8549
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 122ms/step - accuracy: 0.8289 - loss: 0.4676 - val_accuracy: 0.7738 - val_loss: 0.7000
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 87ms/step - accuracy: 0.8468 - loss: 0.4340 - val_accuracy: 0.7748 - val_loss: 0.6938
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 122ms/step - accuracy: 0.8297 - loss: 0.4676 - val_accuracy: 0.7102 - val_loss: 0.9536
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 126ms/step - accuracy: 0.8591 - loss: 0.4044 - val_accuracy: 0.7738 - val_loss: 0.7174
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 123ms/step - accuracy: 0.8560 - loss: 0.3895 - val_accuracy: 0.7558 - val_loss: 0.8106
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - accuracy: 0.8808 - loss: 0.3426 - val_accuracy: 0.7683 - val_loss: 0.7349
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 33s 98ms/step - accuracy: 0.8742 - loss: 0.3559 - val_accuracy: 0.7698 - val_loss: 0.7608
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 25s 122ms/step - accuracy: 0.8866 - loss: 0.3184 - val_accuracy: 0.7788 - val_loss: 0.7154
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 127ms/step - accuracy: 0.8853 - loss: 0.3190 - val_accuracy: 0.7663 - val_loss: 0.8043
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 35s 97ms/step - accuracy: 0.8847 - loss: 0.3144 - val_accuracy: 0.7462 - val_loss: 0.8526
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 26s 123ms/step - accuracy: 0.8926 - loss: 0.2843 - val_accuracy: 0.7367 - val_loss: 0.9108
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 134ms/step - accuracy: 0.8935 - loss: 0.2932 - val_accuracy: 0.7487 - val_loss: 0.8079
# Epoch 23: early stopping
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#
# ---Now testing the model for one audio file---
# The model predicts: metal, and ground truth is: metal.
#
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7279 - loss: 0.8327
# Accuracy on test is 0.7460913062095642
# Test error is 0.8080369830131531
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-883e11155817> in <cell line: 1>()
#      36     print()
#      37
# ---> 38     model2 = design_dnn_model(input_shape)
#      39
#      40     # Selection of the optimizer, loss type and metrics for performance evaluation.
#
# NameError: name 'design_dnn_model' is not defined

# %%
if __name__ == "__main__":
    preprocess_data(source_path=SOURCE_PATH, json_path=JSON_PATH)

    inputs, targets = load_data(json_path=JSON_PATH)

    Xtrain, Xval, Xtest, ytrain, yval, ytest = prepare_datasets(inputs, targets, 0.2)

    input_shape = (Xtrain.shape[1], Xtrain.shape[2])

    model = design_rnn_model(input_shape)

    # Selection of the optimizer, loss type and metrics for performance evaluation.
    model.compile(optimizer = tf.keras.optimizers.AdamW(),
                     loss='sparse_categorical_crossentropy',
                     metrics = ['accuracy']
                  )

    model.summary()

    #Training the model.
    history = model.fit(Xtrain, ytrain,
                        validation_data=(Xval, yval),
                        epochs=50,
                        batch_size=32,
                        callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)],
                      )

    plot_performance(history)

    # Testing the model on never seen before data.
    make_prediction(model, Xtest, ytest, 24)

    test_error, test_accuracy = model.evaluate(Xtest,ytest,verbose=1)
    print("Accuracy on test is {}".format(test_accuracy))
    print("Test error is {}".format(test_error))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 125, 64)             │          19,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57,802 (225.79 KB)
#  Trainable params: 57,802 (225.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 204ms/step - accuracy: 0.2785 - loss: 1.9793 - val_accuracy: 0.4895 - val_loss: 1.4704
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 263ms/step - accuracy: 0.4517 - loss: 1.5520 - val_accuracy: 0.5155 - val_loss: 1.3794
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 68s 195ms/step - accuracy: 0.5004 - loss: 1.3748 - val_accuracy: 0.5310 - val_loss: 1.3075
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 201ms/step - accuracy: 0.5426 - loss: 1.2743 - val_accuracy: 0.5696 - val_loss: 1.1974
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 208ms/step - accuracy: 0.5836 - loss: 1.1840 - val_accuracy: 0.5896 - val_loss: 1.1590
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 227ms/step - accuracy: 0.6002 - loss: 1.1238 - val_accuracy: 0.6166 - val_loss: 1.0983
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 74s 189ms/step - accuracy: 0.6270 - loss: 1.0589 - val_accuracy: 0.5981 - val_loss: 1.0910
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 205ms/step - accuracy: 0.6472 - loss: 0.9975 - val_accuracy: 0.6206 - val_loss: 1.0798
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 86s 225ms/step - accuracy: 0.6600 - loss: 0.9377 - val_accuracy: 0.6311 - val_loss: 1.0580
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 81s 221ms/step - accuracy: 0.6851 - loss: 0.8958 - val_accuracy: 0.6627 - val_loss: 0.9855
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 78s 204ms/step - accuracy: 0.7141 - loss: 0.8360 - val_accuracy: 0.6717 - val_loss: 0.9412
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 223ms/step - accuracy: 0.7365 - loss: 0.7737 - val_accuracy: 0.6827 - val_loss: 0.9625
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 79s 206ms/step - accuracy: 0.7381 - loss: 0.7718 - val_accuracy: 0.6792 - val_loss: 0.9311
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 83s 209ms/step - accuracy: 0.7548 - loss: 0.7388 - val_accuracy: 0.6942 - val_loss: 0.9275
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 85s 227ms/step - accuracy: 0.7567 - loss: 0.7041 - val_accuracy: 0.7082 - val_loss: 0.8814
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 78s 208ms/step - accuracy: 0.7818 - loss: 0.6506 - val_accuracy: 0.7157 - val_loss: 0.8661
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 52s 257ms/step - accuracy: 0.7849 - loss: 0.6363 - val_accuracy: 0.7017 - val_loss: 0.8741
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 190ms/step - accuracy: 0.7936 - loss: 0.5946 - val_accuracy: 0.7192 - val_loss: 0.8289
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 199ms/step - accuracy: 0.8023 - loss: 0.5807 - val_accuracy: 0.7372 - val_loss: 0.8083
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 205ms/step - accuracy: 0.8268 - loss: 0.5169 - val_accuracy: 0.7337 - val_loss: 0.8454
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 235ms/step - accuracy: 0.8298 - loss: 0.4999 - val_accuracy: 0.7282 - val_loss: 0.8414
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 74s 192ms/step - accuracy: 0.8447 - loss: 0.4627 - val_accuracy: 0.7367 - val_loss: 0.8448
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 45s 215ms/step - accuracy: 0.8378 - loss: 0.4672 - val_accuracy: 0.7477 - val_loss: 0.8036
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 83s 220ms/step - accuracy: 0.8607 - loss: 0.4432 - val_accuracy: 0.7397 - val_loss: 0.8110
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 210ms/step - accuracy: 0.8587 - loss: 0.4302 - val_accuracy: 0.7317 - val_loss: 0.8443
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 53s 264ms/step - accuracy: 0.8393 - loss: 0.4844 - val_accuracy: 0.7262 - val_loss: 0.9217
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 69s 197ms/step - accuracy: 0.8620 - loss: 0.4046 - val_accuracy: 0.7548 - val_loss: 0.7865
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 200ms/step - accuracy: 0.8695 - loss: 0.3865 - val_accuracy: 0.7743 - val_loss: 0.7333
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 208ms/step - accuracy: 0.8795 - loss: 0.3609 - val_accuracy: 0.7598 - val_loss: 0.8233
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 88s 237ms/step - accuracy: 0.8832 - loss: 0.3466 - val_accuracy: 0.7367 - val_loss: 0.8690
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 196ms/step - accuracy: 0.8747 - loss: 0.3590 - val_accuracy: 0.7593 - val_loss: 0.8544
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 189ms/step - accuracy: 0.8903 - loss: 0.3238 - val_accuracy: 0.7718 - val_loss: 0.8341
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 203ms/step - accuracy: 0.8966 - loss: 0.3133 - val_accuracy: 0.7508 - val_loss: 0.8981
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 230ms/step - accuracy: 0.8879 - loss: 0.3306 - val_accuracy: 0.7828 - val_loss: 0.7666
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 77s 206ms/step - accuracy: 0.9110 - loss: 0.2677 - val_accuracy: 0.7818 - val_loss: 0.7818
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 81s 200ms/step - accuracy: 0.9182 - loss: 0.2500 - val_accuracy: 0.7598 - val_loss: 0.8504
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 224ms/step - accuracy: 0.9067 - loss: 0.2818 - val_accuracy: 0.7663 - val_loss: 0.8345
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 78s 204ms/step - accuracy: 0.9163 - loss: 0.2610 - val_accuracy: 0.7778 - val_loss: 0.8158
# Epoch 38: early stopping
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step
#
# ---Now testing the model for one audio file---
# The model predicts: metal, and ground truth is: metal.
#
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.7794 - loss: 0.8278
# Accuracy on test is 0.7717323303222656
# Test error is 0.8460813760757446
