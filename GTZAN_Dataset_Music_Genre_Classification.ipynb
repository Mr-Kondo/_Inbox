# %% [markdown]
# <a href="https://colab.research.google.com/github/MS-H2020/Open/blob/main/GTZAN_Dataset_Music_Genre_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [GTZAN Dataset - Music Genre Classification](https://www.kaggle.com/datasets/andradaolteanu/gtzan-dataset-music-genre-classification)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
shutil.unpack_archive('/content/drive/MyDrive/archive.zip', './data')

# %% [markdown]
# ## Reffering to [Kaggle, Music Genre Classification using CNN](https://www.kaggle.com/code/soumyasharma20/music-genre-classification-using-cnn)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import json
import librosa
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf

# make sure ffmpeg is installed as backend.
# !apt install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# Dataset location
SOURCE_PATH = '/content/data/Data/genres_original'

# Path to labels and processed data file, json format.
JSON_PATH = './data.json'

# Sampling rate.
sr = 22050

# Let's make sure all files have the same amount of samples and pick a duration right under 30 seconds.
TOTAL_SAMPLES = 29 * sr

# The dataset contains 999 files. Lets make it bigger.
# X amount of slices => X times more training examples.
NUM_SLICES = 10
SAMPLES_PER_SLICE = int(TOTAL_SAMPLES / NUM_SLICES)

# %% [markdown]
# #### [【機械学習】音声データ水増し（オーギュメンテーション）チートシート！実践的内容網羅＆海外事例も紹介【Python】](https://hanadamaya.net/audio_data_aug_python/)

# %%
def white_noise(x, rate=0.002):
    return x + rate*np.random.randn(len(x))
#data_whitenoise = white_noise(data)

# %%
def preprocess_data(source_path, json_path):

    # Let's create a dictionary of labels and processed data.
    mydict = {
        "labels": [],
        "mfcc": []
        }

    # Let's browse each file, slice it and generate the 13 band mfcc for each slice.
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(source_path)):
        for file in filenames:
            # exclude a corrupted wav file that makes everything crash.
            if os.path.join(dirpath, file) != '/content/data/Data/genres_original/jazz/jazz.00054.wav':
                song, sr = librosa.load(os.path.join(dirpath, file), duration=29)
                noised_song = white_noise(song)
                for s in range(NUM_SLICES):
                    start_sample = SAMPLES_PER_SLICE * s
                    end_sample = start_sample + SAMPLES_PER_SLICE
                    mfcc = librosa.feature.mfcc(y=song[start_sample:end_sample], sr=sr, n_mfcc=13)
                    mfcc = mfcc.T
                    mydict["labels"].append(i-1)
                    mydict["mfcc"].append(mfcc.tolist())
            else:
                pass

    # Let's write the dictionary in a json file.
    with open(json_path, 'w') as f:
        json.dump(mydict, f)
    f.close()

# %%
def load_data(json_path):

    with open(json_path, 'r') as f:
        data = json.load(f)
    f.close()

    # Let's load our data into numpy arrays for TensorFlow compatibility.
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    return X, y

# %%
def prepare_datasets(inputs, targets, split_size):

    # Creating a validation set and a test set.
    inputs_train, inputs_val, targets_train, targets_val = train_test_split(inputs, targets, test_size=split_size, stratify=targets)
    inputs_train, inputs_test, targets_train, targets_test = train_test_split(inputs_train, targets_train, test_size=split_size, stratify=targets_train)

    # Our CNN model expects 3D input shape.
    inputs_train = inputs_train[..., np.newaxis]
    inputs_val = inputs_val[..., np.newaxis]
    inputs_test = inputs_test[..., np.newaxis]

    return inputs_train, inputs_val, inputs_test, targets_train, targets_val, targets_test

# %%
def design_cnn_model(input_shape):

    # Let's design the model architecture.
    model = tf.keras.models.Sequential([

        tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        tf.keras.layers.BatchNormalization(),

        tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        tf.keras.layers.BatchNormalization(),

        tf.keras.layers.Conv2D(32, (2,2), activation='relu'),
        tf.keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.3),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(len(np.unique(targets)), activation='softmax')
    ])

    return model

# %% [markdown]
# ### Reffering to RNN model : [Kaggle, intro to audio with Deep Learning](https://www.kaggle.com/code/riadalmadani/intro-to-audio-with-deep-learning)

# %%
def design_rnn_model(input_shape):

    # Let's design the model architecture.
    model = tf.keras.models.Sequential([

        # 64 represnets the number of units NOT cells
        # the number of cells equal to the numper of steps which is 130 here

        tf.keras.layers.LSTM(64,input_shape=input_shape, return_sequences=True),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(len(np.unique(targets)), activation='softmax')
    ])

    return model

# %%
def make_prediction(model, X, y, idx):

    genre_dict = {
        0 : "blues",
        1 : "classical",
        2 : "country",
        3 : "disco",
        4 : "hiphop",
        5 : "jazz",
        6 : "metal",
        7 : "pop",
        8 : "reggae",
        9 : "rock",
        }

    predictions = model.predict(X)
    genre = np.argmax(predictions[idx])

    print("\n---Now testing the model for one audio file---\nThe model predicts: {}, and ground truth is: {}.\n".format(genre_dict[genre], genre_dict[y[idx]]))

# %%
def plot_performance(hist):

    acc = hist.history['accuracy']
    val_acc = hist.history['val_accuracy']
    loss = hist.history['loss']
    val_loss = hist.history['val_loss']

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'r', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrix(labels, predictions, threshold=0.5):
  cm = confusion_matrix(labels, predictions > threshold)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(threshold))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))

# %%
if __name__ == "__main__":

#    preprocess_data(source_path=SOURCE_PATH, json_path=JSON_PATH)

#    inputs, targets = load_data(json_path=JSON_PATH)

#    Xtrain, Xval, Xtest, ytrain, yval, ytest = prepare_datasets(inputs, targets, 0.2)

#    input_shape = (Xtrain.shape[1], Xtrain.shape[2], 1)

    model = design_cnn_model(input_shape)

    # Selection of the optimizer, loss type and metrics for performance evaluation.
    model.compile(optimizer = tf.keras.optimizers.AdamW(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics = ['accuracy']
                  )

    model.summary()

    #Training the model.
    history = model.fit(Xtrain, ytrain,
                        validation_data=(Xval, yval),
                        epochs=50,
                        batch_size=32,
                         callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)],
                        )

    plot_performance(history)

    # Testing the model on never seen before data.
    make_prediction(model, Xtest, ytest, 24)

    test_error , test_accuracy = model.evaluate(Xtest,ytest,verbose=1)
    print("Accuracy on test is {}".format(test_accuracy))
    print("Test error is {}".format(test_error))
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_27 (Conv2D)                   │ (None, 123, 11, 32)         │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_27 (MaxPooling2D)      │ (None, 62, 6, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_27               │ (None, 62, 6, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_28 (Conv2D)                   │ (None, 60, 4, 32)           │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_28 (MaxPooling2D)      │ (None, 30, 2, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_28               │ (None, 30, 2, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_29 (Conv2D)                   │ (None, 29, 1, 32)           │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_29 (MaxPooling2D)      │ (None, 15, 1, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_29               │ (None, 15, 1, 32)           │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 15, 1, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_7           │ (None, 32)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,842 (65.79 KB)
#  Trainable params: 16,650 (65.04 KB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 202ms/step - accuracy: 0.1625 - loss: 2.2659 - val_accuracy: 0.2082 - val_loss: 2.1361
# Epoch 2/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 258ms/step - accuracy: 0.3992 - loss: 1.8623 - val_accuracy: 0.4049 - val_loss: 1.7997
# Epoch 3/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 216ms/step - accuracy: 0.4710 - loss: 1.6463 - val_accuracy: 0.5030 - val_loss: 1.5619
# Epoch 4/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 137ms/step - accuracy: 0.5116 - loss: 1.4882 - val_accuracy: 0.5310 - val_loss: 1.4155
# Epoch 5/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 284ms/step - accuracy: 0.5480 - loss: 1.3976 - val_accuracy: 0.5596 - val_loss: 1.3284
# Epoch 6/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 237ms/step - accuracy: 0.5580 - loss: 1.3265 - val_accuracy: 0.5836 - val_loss: 1.2659
# Epoch 7/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 224ms/step - accuracy: 0.5770 - loss: 1.2686 - val_accuracy: 0.5956 - val_loss: 1.2245
# Epoch 8/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 143ms/step - accuracy: 0.6135 - loss: 1.1870 - val_accuracy: 0.6156 - val_loss: 1.1718
# Epoch 9/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 214ms/step - accuracy: 0.6068 - loss: 1.1632 - val_accuracy: 0.6296 - val_loss: 1.1340
# Epoch 10/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 201ms/step - accuracy: 0.6234 - loss: 1.1357 - val_accuracy: 0.6366 - val_loss: 1.1057
# Epoch 11/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 229ms/step - accuracy: 0.6463 - loss: 1.0715 - val_accuracy: 0.6466 - val_loss: 1.0695
# Epoch 12/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 224ms/step - accuracy: 0.6567 - loss: 1.0397 - val_accuracy: 0.6612 - val_loss: 1.0269
# Epoch 13/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.6687 - loss: 1.0095 - val_accuracy: 0.6637 - val_loss: 1.0093
# Epoch 14/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 204ms/step - accuracy: 0.6800 - loss: 0.9766 - val_accuracy: 0.6732 - val_loss: 0.9748
# Epoch 15/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 159ms/step - accuracy: 0.6795 - loss: 0.9774 - val_accuracy: 0.6777 - val_loss: 0.9620
# Epoch 16/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 238ms/step - accuracy: 0.6984 - loss: 0.9336 - val_accuracy: 0.6892 - val_loss: 0.9412
# Epoch 17/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.7057 - loss: 0.9110 - val_accuracy: 0.6762 - val_loss: 0.9406
# Epoch 18/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 146ms/step - accuracy: 0.7041 - loss: 0.9040 - val_accuracy: 0.6957 - val_loss: 0.9146
# Epoch 19/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - accuracy: 0.6995 - loss: 0.8902 - val_accuracy: 0.6967 - val_loss: 0.8862
# Epoch 20/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 243ms/step - accuracy: 0.7278 - loss: 0.8395 - val_accuracy: 0.6927 - val_loss: 0.8858
# Epoch 21/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 228ms/step - accuracy: 0.7132 - loss: 0.8639 - val_accuracy: 0.7042 - val_loss: 0.8754
# Epoch 22/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 240ms/step - accuracy: 0.7307 - loss: 0.8215 - val_accuracy: 0.6942 - val_loss: 0.8785
# Epoch 23/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 177ms/step - accuracy: 0.7305 - loss: 0.8080 - val_accuracy: 0.7142 - val_loss: 0.8402
# Epoch 24/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 206ms/step - accuracy: 0.7267 - loss: 0.8312 - val_accuracy: 0.7132 - val_loss: 0.8518
# Epoch 25/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 225ms/step - accuracy: 0.7367 - loss: 0.8036 - val_accuracy: 0.7232 - val_loss: 0.8257
# Epoch 26/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 246ms/step - accuracy: 0.7368 - loss: 0.7837 - val_accuracy: 0.7212 - val_loss: 0.8241
# Epoch 27/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 233ms/step - accuracy: 0.7402 - loss: 0.7852 - val_accuracy: 0.7297 - val_loss: 0.8007
# Epoch 28/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 221ms/step - accuracy: 0.7446 - loss: 0.7627 - val_accuracy: 0.7257 - val_loss: 0.8067
# Epoch 29/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.7374 - loss: 0.7611 - val_accuracy: 0.7272 - val_loss: 0.7816
# Epoch 30/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 177ms/step - accuracy: 0.7548 - loss: 0.7382 - val_accuracy: 0.7292 - val_loss: 0.7928
# Epoch 31/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 240ms/step - accuracy: 0.7599 - loss: 0.7150 - val_accuracy: 0.7337 - val_loss: 0.7679
# Epoch 32/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.7620 - loss: 0.7371 - val_accuracy: 0.7302 - val_loss: 0.7631
# Epoch 33/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 249ms/step - accuracy: 0.7693 - loss: 0.7062 - val_accuracy: 0.7362 - val_loss: 0.7574
# Epoch 34/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 217ms/step - accuracy: 0.7775 - loss: 0.6827 - val_accuracy: 0.7392 - val_loss: 0.7576
# Epoch 35/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 58s 390ms/step - accuracy: 0.7665 - loss: 0.6973 - val_accuracy: 0.7412 - val_loss: 0.7460
# Epoch 36/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.7677 - loss: 0.6876 - val_accuracy: 0.7462 - val_loss: 0.7440
# Epoch 37/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 225ms/step - accuracy: 0.7843 - loss: 0.6584 - val_accuracy: 0.7462 - val_loss: 0.7348
# Epoch 38/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 45s 265ms/step - accuracy: 0.7849 - loss: 0.6659 - val_accuracy: 0.7508 - val_loss: 0.7382
# Epoch 39/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 55s 401ms/step - accuracy: 0.7783 - loss: 0.6568 - val_accuracy: 0.7347 - val_loss: 0.7507
# Epoch 40/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 32s 306ms/step - accuracy: 0.7779 - loss: 0.6599 - val_accuracy: 0.7382 - val_loss: 0.7362
# Epoch 41/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 260ms/step - accuracy: 0.7850 - loss: 0.6393 - val_accuracy: 0.7538 - val_loss: 0.7202
# Epoch 42/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 144ms/step - accuracy: 0.7924 - loss: 0.6247 - val_accuracy: 0.7528 - val_loss: 0.7158
# Epoch 43/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.7969 - loss: 0.6162 - val_accuracy: 0.7623 - val_loss: 0.7125
# Epoch 44/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 230ms/step - accuracy: 0.7940 - loss: 0.6162 - val_accuracy: 0.7523 - val_loss: 0.7166
# Epoch 45/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 230ms/step - accuracy: 0.7870 - loss: 0.6287 - val_accuracy: 0.7548 - val_loss: 0.7179
# Epoch 46/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 261ms/step - accuracy: 0.7898 - loss: 0.6195 - val_accuracy: 0.7508 - val_loss: 0.7275
# Epoch 47/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 202ms/step - accuracy: 0.7963 - loss: 0.6016 - val_accuracy: 0.7548 - val_loss: 0.7110
# Epoch 48/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 173ms/step - accuracy: 0.8006 - loss: 0.5887 - val_accuracy: 0.7648 - val_loss: 0.6947
# Epoch 49/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 224ms/step - accuracy: 0.8043 - loss: 0.5928 - val_accuracy: 0.7688 - val_loss: 0.6945
# Epoch 50/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 203ms/step - accuracy: 0.8062 - loss: 0.5985 - val_accuracy: 0.7673 - val_loss: 0.6849
# Epoch 51/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.8194 - loss: 0.5507 - val_accuracy: 0.7558 - val_loss: 0.7014
# Epoch 52/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 229ms/step - accuracy: 0.8108 - loss: 0.5690 - val_accuracy: 0.7623 - val_loss: 0.7125
# Epoch 53/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 248ms/step - accuracy: 0.8173 - loss: 0.5566 - val_accuracy: 0.7688 - val_loss: 0.6733
# Epoch 54/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 221ms/step - accuracy: 0.8095 - loss: 0.5576 - val_accuracy: 0.7593 - val_loss: 0.7088
# Epoch 55/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 168ms/step - accuracy: 0.8329 - loss: 0.5271 - val_accuracy: 0.7523 - val_loss: 0.7052
# Epoch 56/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 229ms/step - accuracy: 0.8286 - loss: 0.5341 - val_accuracy: 0.7638 - val_loss: 0.6933
# Epoch 57/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - accuracy: 0.8242 - loss: 0.5376 - val_accuracy: 0.7763 - val_loss: 0.6639
# Epoch 58/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 233ms/step - accuracy: 0.8198 - loss: 0.5507 - val_accuracy: 0.7748 - val_loss: 0.6641
# Epoch 59/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 198ms/step - accuracy: 0.8359 - loss: 0.5096 - val_accuracy: 0.7713 - val_loss: 0.6711
# Epoch 60/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 221ms/step - accuracy: 0.8255 - loss: 0.5262 - val_accuracy: 0.7758 - val_loss: 0.6625
# Epoch 61/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 238ms/step - accuracy: 0.8247 - loss: 0.5319 - val_accuracy: 0.7763 - val_loss: 0.6696
# Epoch 62/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 255ms/step - accuracy: 0.8268 - loss: 0.5165 - val_accuracy: 0.7708 - val_loss: 0.6690
# Epoch 63/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 194ms/step - accuracy: 0.8305 - loss: 0.5181 - val_accuracy: 0.7728 - val_loss: 0.6619
# Epoch 64/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 217ms/step - accuracy: 0.8179 - loss: 0.5233 - val_accuracy: 0.7728 - val_loss: 0.6606
# Epoch 65/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 34s 146ms/step - accuracy: 0.8269 - loss: 0.5162 - val_accuracy: 0.7718 - val_loss: 0.6627
# Epoch 66/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 216ms/step - accuracy: 0.8341 - loss: 0.5009 - val_accuracy: 0.7743 - val_loss: 0.6587
# Epoch 67/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 176ms/step - accuracy: 0.8353 - loss: 0.5002 - val_accuracy: 0.7768 - val_loss: 0.6402
# Epoch 68/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 243ms/step - accuracy: 0.8442 - loss: 0.4805 - val_accuracy: 0.7698 - val_loss: 0.6741
# Epoch 69/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 248ms/step - accuracy: 0.8383 - loss: 0.4907 - val_accuracy: 0.7798 - val_loss: 0.6444
# Epoch 70/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 196ms/step - accuracy: 0.8375 - loss: 0.4842 - val_accuracy: 0.7738 - val_loss: 0.6588
# Epoch 71/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - accuracy: 0.8371 - loss: 0.4942 - val_accuracy: 0.7878 - val_loss: 0.6393
# Epoch 72/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 153ms/step - accuracy: 0.8339 - loss: 0.4911 - val_accuracy: 0.7723 - val_loss: 0.6655
# Epoch 73/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 204ms/step - accuracy: 0.8482 - loss: 0.4613 - val_accuracy: 0.7758 - val_loss: 0.6573
# Epoch 74/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 223ms/step - accuracy: 0.8341 - loss: 0.4947 - val_accuracy: 0.7773 - val_loss: 0.6441
# Epoch 75/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 19s 186ms/step - accuracy: 0.8456 - loss: 0.4579 - val_accuracy: 0.7778 - val_loss: 0.6539
# Epoch 76/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 18s 178ms/step - accuracy: 0.8485 - loss: 0.4479 - val_accuracy: 0.7823 - val_loss: 0.6348
# Epoch 77/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 247ms/step - accuracy: 0.8369 - loss: 0.4799 - val_accuracy: 0.7708 - val_loss: 0.6587
# Epoch 78/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 233ms/step - accuracy: 0.8366 - loss: 0.4752 - val_accuracy: 0.7783 - val_loss: 0.6399
# Epoch 79/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 21s 214ms/step - accuracy: 0.8554 - loss: 0.4435 - val_accuracy: 0.7843 - val_loss: 0.6278
# Epoch 80/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 211ms/step - accuracy: 0.8417 - loss: 0.4661 - val_accuracy: 0.7838 - val_loss: 0.6241
# Epoch 81/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 220ms/step - accuracy: 0.8545 - loss: 0.4406 - val_accuracy: 0.7598 - val_loss: 0.6963
# Epoch 82/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 208ms/step - accuracy: 0.8495 - loss: 0.4630 - val_accuracy: 0.7878 - val_loss: 0.6377
# Epoch 83/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 44s 238ms/step - accuracy: 0.8523 - loss: 0.4280 - val_accuracy: 0.7748 - val_loss: 0.6539
# Epoch 84/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 225ms/step - accuracy: 0.8530 - loss: 0.4221 - val_accuracy: 0.7833 - val_loss: 0.6327
# Epoch 85/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 142ms/step - accuracy: 0.8534 - loss: 0.4233 - val_accuracy: 0.7878 - val_loss: 0.6166
# Epoch 86/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 21s 213ms/step - accuracy: 0.8569 - loss: 0.4275 - val_accuracy: 0.7868 - val_loss: 0.6288
# Epoch 87/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 153ms/step - accuracy: 0.8616 - loss: 0.4034 - val_accuracy: 0.7953 - val_loss: 0.6139
# Epoch 88/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - accuracy: 0.8531 - loss: 0.4345 - val_accuracy: 0.7963 - val_loss: 0.6152
# Epoch 89/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 154ms/step - accuracy: 0.8626 - loss: 0.4098 - val_accuracy: 0.7993 - val_loss: 0.6050
# Epoch 90/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 236ms/step - accuracy: 0.8646 - loss: 0.4172 - val_accuracy: 0.7893 - val_loss: 0.6193
# Epoch 91/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 250ms/step - accuracy: 0.8644 - loss: 0.4050 - val_accuracy: 0.7978 - val_loss: 0.6062
# Epoch 92/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 234ms/step - accuracy: 0.8580 - loss: 0.4103 - val_accuracy: 0.7733 - val_loss: 0.6578
# Epoch 93/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 34s 160ms/step - accuracy: 0.8641 - loss: 0.4016 - val_accuracy: 0.7938 - val_loss: 0.6112
# Epoch 94/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 229ms/step - accuracy: 0.8696 - loss: 0.3962 - val_accuracy: 0.7783 - val_loss: 0.6498
# Epoch 95/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 32s 138ms/step - accuracy: 0.8621 - loss: 0.4083 - val_accuracy: 0.7908 - val_loss: 0.6044
# Epoch 96/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 234ms/step - accuracy: 0.8684 - loss: 0.3985 - val_accuracy: 0.7908 - val_loss: 0.6192
# Epoch 97/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.8623 - loss: 0.3972 - val_accuracy: 0.7938 - val_loss: 0.6098
# Epoch 98/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 217ms/step - accuracy: 0.8766 - loss: 0.3809 - val_accuracy: 0.7838 - val_loss: 0.6385
# Epoch 99/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 224ms/step - accuracy: 0.8776 - loss: 0.3789 - val_accuracy: 0.7953 - val_loss: 0.6092
# Epoch 100/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 32s 137ms/step - accuracy: 0.8710 - loss: 0.3839 - val_accuracy: 0.7773 - val_loss: 0.6630
# Epoch 101/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 232ms/step - accuracy: 0.8715 - loss: 0.3913 - val_accuracy: 0.7958 - val_loss: 0.6086
# Epoch 102/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 195ms/step - accuracy: 0.8689 - loss: 0.3794 - val_accuracy: 0.7793 - val_loss: 0.6519
# Epoch 103/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 24s 240ms/step - accuracy: 0.8694 - loss: 0.3831 - val_accuracy: 0.7863 - val_loss: 0.6295
# Epoch 104/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.8801 - loss: 0.3617 - val_accuracy: 0.7968 - val_loss: 0.6021
# Epoch 105/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 219ms/step - accuracy: 0.8734 - loss: 0.3735 - val_accuracy: 0.7948 - val_loss: 0.6276
# Epoch 106/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 168ms/step - accuracy: 0.8733 - loss: 0.3729 - val_accuracy: 0.8033 - val_loss: 0.5953
# Epoch 107/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 230ms/step - accuracy: 0.8748 - loss: 0.3666 - val_accuracy: 0.8023 - val_loss: 0.5971
# Epoch 108/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 31s 129ms/step - accuracy: 0.8738 - loss: 0.3663 - val_accuracy: 0.7968 - val_loss: 0.6118
# Epoch 109/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 225ms/step - accuracy: 0.8790 - loss: 0.3573 - val_accuracy: 0.7873 - val_loss: 0.6366
# Epoch 110/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 142ms/step - accuracy: 0.8778 - loss: 0.3706 - val_accuracy: 0.7948 - val_loss: 0.6069
# Epoch 111/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 241ms/step - accuracy: 0.8781 - loss: 0.3644 - val_accuracy: 0.8028 - val_loss: 0.5941
# Epoch 112/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 224ms/step - accuracy: 0.8821 - loss: 0.3454 - val_accuracy: 0.7848 - val_loss: 0.6263
# Epoch 113/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - accuracy: 0.8823 - loss: 0.3466 - val_accuracy: 0.7993 - val_loss: 0.5951
# Epoch 114/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 35s 161ms/step - accuracy: 0.8767 - loss: 0.3464 - val_accuracy: 0.7973 - val_loss: 0.6033
# Epoch 115/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 219ms/step - accuracy: 0.8919 - loss: 0.3269 - val_accuracy: 0.8103 - val_loss: 0.5808
# Epoch 116/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - accuracy: 0.8868 - loss: 0.3360 - val_accuracy: 0.8003 - val_loss: 0.5855
# Epoch 117/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 236ms/step - accuracy: 0.8820 - loss: 0.3447 - val_accuracy: 0.7973 - val_loss: 0.5971
# Epoch 118/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 224ms/step - accuracy: 0.8830 - loss: 0.3441 - val_accuracy: 0.7983 - val_loss: 0.6056
# Epoch 119/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 224ms/step - accuracy: 0.8921 - loss: 0.3441 - val_accuracy: 0.7953 - val_loss: 0.5917
# Epoch 120/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.8798 - loss: 0.3548 - val_accuracy: 0.8033 - val_loss: 0.5944
# Epoch 121/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 20s 199ms/step - accuracy: 0.8920 - loss: 0.3238 - val_accuracy: 0.8048 - val_loss: 0.5906
# Epoch 122/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - accuracy: 0.8851 - loss: 0.3279 - val_accuracy: 0.8068 - val_loss: 0.5809
# Epoch 123/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 230ms/step - accuracy: 0.8877 - loss: 0.3178 - val_accuracy: 0.7838 - val_loss: 0.6338
# Epoch 124/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 33s 149ms/step - accuracy: 0.8875 - loss: 0.3307 - val_accuracy: 0.8073 - val_loss: 0.5830
# Epoch 125/200
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 28s 224ms/step - accuracy: 0.8910 - loss: 0.3161 - val_accuracy: 0.7803 - val_loss: 0.6707
# Epoch 125: early stopping
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
#
# ---Now testing the model for one audio file---
# The model predicts: pop, and ground truth is: pop.
#
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.7991 - loss: 0.6143
# Accuracy on test is 0.7892432808876038
# Test error is 0.6329175233840942

# %%
if __name__ == "__main__":

    preprocess_data(source_path=SOURCE_PATH, json_path=JSON_PATH)

    inputs, targets = load_data(json_path=JSON_PATH)

    Xtrain, Xval, Xtest, ytrain, yval, ytest = prepare_datasets(inputs, targets, 0.2)

    input_shape = (Xtrain.shape[1], Xtrain.shape[2])

    model = design_rnn_model(input_shape)

    # Selection of the optimizer, loss type and metrics for performance evaluation.
    model.compile(optimizer = tf.keras.optimizers.AdamW(),
                     loss='sparse_categorical_crossentropy',
                     metrics = ['accuracy']
                  )

    model.summary()

    #Training the model.
    history = model.fit(Xtrain, ytrain,
                        validation_data=(Xval, yval),
                        epochs=50,
                        batch_size=32,
                        callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)],
                      )

    plot_performance(history)

    # Testing the model on never seen before data.
    make_prediction(model, Xtest, ytest, 24)

    test_error, test_accuracy = model.evaluate(Xtest,ytest,verbose=1)
    print("Accuracy on test is {}".format(test_accuracy))
    print("Test error is {}".format(test_error))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 125, 64)             │          19,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57,802 (225.79 KB)
#  Trainable params: 57,802 (225.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 184ms/step - accuracy: 0.3000 - loss: 1.9889 - val_accuracy: 0.4620 - val_loss: 1.4965
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 235ms/step - accuracy: 0.4741 - loss: 1.4554 - val_accuracy: 0.5155 - val_loss: 1.3621
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 178ms/step - accuracy: 0.5243 - loss: 1.3223 - val_accuracy: 0.5480 - val_loss: 1.2556
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 37s 183ms/step - accuracy: 0.5815 - loss: 1.2126 - val_accuracy: 0.5906 - val_loss: 1.1941
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 188ms/step - accuracy: 0.5755 - loss: 1.2184 - val_accuracy: 0.5631 - val_loss: 1.2245
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 241ms/step - accuracy: 0.6067 - loss: 1.1367 - val_accuracy: 0.6061 - val_loss: 1.1319
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 78s 219ms/step - accuracy: 0.6506 - loss: 1.0291 - val_accuracy: 0.6286 - val_loss: 1.0817
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 77s 194ms/step - accuracy: 0.6760 - loss: 0.9472 - val_accuracy: 0.6517 - val_loss: 1.0254
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 209ms/step - accuracy: 0.7087 - loss: 0.8956 - val_accuracy: 0.6471 - val_loss: 1.0554
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 75s 173ms/step - accuracy: 0.7082 - loss: 0.8821 - val_accuracy: 0.6657 - val_loss: 0.9726
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 189ms/step - accuracy: 0.7298 - loss: 0.8136 - val_accuracy: 0.6807 - val_loss: 0.9352
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 216ms/step - accuracy: 0.7466 - loss: 0.7712 - val_accuracy: 0.6872 - val_loss: 0.9407
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 86s 233ms/step - accuracy: 0.7577 - loss: 0.7144 - val_accuracy: 0.6957 - val_loss: 0.9329
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 77s 209ms/step - accuracy: 0.7698 - loss: 0.6868 - val_accuracy: 0.7017 - val_loss: 0.8810
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 198ms/step - accuracy: 0.7788 - loss: 0.6528 - val_accuracy: 0.6882 - val_loss: 0.9185
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 36s 171ms/step - accuracy: 0.8040 - loss: 0.6107 - val_accuracy: 0.7367 - val_loss: 0.8144
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 55s 241ms/step - accuracy: 0.8031 - loss: 0.5984 - val_accuracy: 0.7257 - val_loss: 0.8222
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 183ms/step - accuracy: 0.8164 - loss: 0.5628 - val_accuracy: 0.7292 - val_loss: 0.8391
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 179ms/step - accuracy: 0.8210 - loss: 0.5298 - val_accuracy: 0.7367 - val_loss: 0.8544
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 179ms/step - accuracy: 0.8340 - loss: 0.4886 - val_accuracy: 0.7422 - val_loss: 0.8400
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 51s 232ms/step - accuracy: 0.8460 - loss: 0.4584 - val_accuracy: 0.7508 - val_loss: 0.7805
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 228ms/step - accuracy: 0.8521 - loss: 0.4677 - val_accuracy: 0.7197 - val_loss: 0.8793
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 36s 182ms/step - accuracy: 0.8442 - loss: 0.4829 - val_accuracy: 0.7407 - val_loss: 0.8147
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 207ms/step - accuracy: 0.8669 - loss: 0.4128 - val_accuracy: 0.7628 - val_loss: 0.8284
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 83s 211ms/step - accuracy: 0.8802 - loss: 0.3810 - val_accuracy: 0.7457 - val_loss: 0.8573
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 76s 181ms/step - accuracy: 0.8690 - loss: 0.3888 - val_accuracy: 0.7497 - val_loss: 0.8400
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 205ms/step - accuracy: 0.8648 - loss: 0.3966 - val_accuracy: 0.7628 - val_loss: 0.7887
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 81s 201ms/step - accuracy: 0.8881 - loss: 0.3293 - val_accuracy: 0.7718 - val_loss: 0.8063
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 55s 270ms/step - accuracy: 0.8913 - loss: 0.3313 - val_accuracy: 0.7628 - val_loss: 0.8449
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 64s 182ms/step - accuracy: 0.8861 - loss: 0.3536 - val_accuracy: 0.7397 - val_loss: 0.9117
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 170ms/step - accuracy: 0.8934 - loss: 0.3246 - val_accuracy: 0.7688 - val_loss: 0.8282
# Epoch 31: early stopping
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step
#
# ---Now testing the model for one audio file---
# The model predicts: disco, and ground truth is: disco.
#
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.7876 - loss: 0.8178
# Accuracy on test is 0.7711069583892822
# Test error is 0.8545954823493958
